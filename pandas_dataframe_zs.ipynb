# %% [markdown]
# <a href="https://colab.research.google.com/github/zilles-vub/real-world-machine-learning/blob/python3/pandas_dataframe_zs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
miaserie = pd.Series([4, 5, 6.5, 7], index=['first', 'second', 'third', 'fourth'])
miaserie['third']
# Out:
# 6.5

# %%
miaserie.iloc[2]
# Out:
# 6.5

# %%
miaserie
# Out:
# first     4.0
# second    5.0
# third     6.5
# fourth    7.0
# dtype: float64

# %%
type(miaserie.iloc[0])
# Out:
# numpy.float64

# %%
s2 = pd.Series([4, 5, 6, 7], index=['first', 'second', 'third', 'fourth'])
s2['third']
# Out:
# 6

# %%
s3 = pd.Series([4, 5, 'third', 7.0], index=['first', 'second', 'third', 'fourth'])
s3
# Out:
# first         4
# second        5
# third     third
# fourth      7.0
# dtype: object

# %%
#type(s3.iloc[0])
#type(s3.iloc[2])
type(s3.iloc[-1])
# Out:
# float

# %%
s3*2
# Out:
# first              8
# second            10
# third     thirdthird
# fourth          14.0
# dtype: object

# %%
s2>5
# Out:
# first     False
# second    False
# third      True
# fourth     True
# dtype: bool

# %%
d = {'one': pd.Series([1., 2., 3.], index=['a', 'b', 'c']),
     'two': pd.Series([1.2, 2.1, 3.5, 4.9], index=['a', 'b', 'c', 'd'])}

# %%
nonomog = pd.Series([1, 2, 4.5, 8], index=['a', 2, 3, 'd'])
nonomog
# Out:
# a    1.0
# 2    2.0
# 3    4.5
# d    8.0
# dtype: float64

# %%
d
# Out:
# {'one': a    1.0
#  b    2.0
#  c    3.0
#  dtype: float64,
#  'two': a    1.0
#  b    2.0
#  c    3.0
#  d    4.0
#  dtype: float64}

# %%
d['two']+nonomog
# Out:
# 2     NaN
# 3     NaN
# a     2.0
# b     NaN
# c     NaN
# d    12.0
# dtype: float64

# %%
ser1 = pd.Series([1, 2, 3], index=['b', 'a', 'c'])
ser2 = pd.Series([1, 2, 3], index=['a', 'b', 'd'])
ser1 + ser2
# Out:
# a    3.0
# b    3.0
# c    NaN
# d    NaN
# dtype: float64

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#    one  two
# a  1.0  1.2
# b  2.0  2.1
# c  3.0  3.5
# d  NaN  4.9

# %%
df2 = pd.DataFrame(ser1 + ser2)
df2
# Out:
#      0
# a  3.0
# b  3.0
# c  NaN
# d  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, a to d
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     3 non-null      float64
#  1   two     4 non-null      float64
# dtypes: float64(2)
# memory usage: 268.0+ bytes

# %%
df['one']
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
print(df['one'].iloc[0])
df['one']['a']
# Out:
# 1.0
# 1.0

# %%
df['one'] # select by column
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
df['one'][0]
df['one']['a']
# Out:
# 1.0

# %%
df
# Out:
#    one  two
# a  1.0  1.2
# b  2.0  2.1
# c  3.0  3.5
# d  NaN  4.9

# %%
df.loc['a'] # select by row label
# Out:
# one    1.0
# two    1.2
# Name: a, dtype: float64

# %%
df.iloc[0] # select by column index
# Out:
# one    1.0
# two    1.2
# Name: a, dtype: float64

# %%
df2 = pd.DataFrame(np.random.rand(5, 80))
print(df2)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.215288  0.361235  0.380967  0.148923  0.080799  0.537885  0.157919
# 1  0.614170  0.468499  0.312736  0.888089  0.894824  0.929299  0.575345
# 2  0.761629  0.222343  0.701367  0.864994  0.246516  0.742250  0.335103
# 3  0.941525  0.000548  0.108003  0.174733  0.398294  0.897524  0.762559
# 4  0.784348  0.860691  0.785779  0.702496  0.956993  0.479088  0.710679
#
#          7         8         9   ...        70        71        72        73  \
# 0  0.165859  0.475999  0.286180  ...  0.292653  0.818828  0.340761  0.203901
# 1  0.575567  0.556181  0.160614  ...  0.136264  0.600864  0.984860  0.129083
# 2  0.974070  0.698237  0.860317  ...  0.397905  0.662400  0.722252  0.585836
# 3  0.965510  0.633607  0.297035  ...  0.930759  0.706613  0.359910  0.625968
# 4  0.469689  0.397802  0.838061  ...  0.604417  0.647839  0.654136  0.367987
#
#          74        75        76        77        78        79
# ...

# %%
df2[2]
# Out:
# 0    0.380967
# 1    0.312736
# 2    0.701367
# 3    0.108003
# 4    0.785779
# Name: 2, dtype: float64

# %%
df2.loc[2]
# Out:
# 0     0.761629
# 1     0.222343
# 2     0.701367
# 3     0.864994
# 4     0.246516
#         ...
# 75    0.917743
# 76    0.766035
# 77    0.158402
# 78    0.024493
# 79    0.515662
# Name: 2, Length: 80, dtype: float64

# %%
df
# Out:
#    one  two
# a  1.0  1.2
# b  2.0  2.1
# c  3.0  3.5
# d  NaN  4.9

# %%
df.loc[[False, True, True, False]]
# Out:
#    one  two
# b  2.0  2.1
# c  3.0  3.5

# %%
# select * from df where 'two' > 2
list(df['two']>2)
# Out:
# [False, True, True, True]

# %%
# select * from df where 'two' > 2 and 'one' > 2
list((df['two']>2) & (df['one']>2))
# Out:
# [False, False, True, False]

# %%
# so[(so['score'] >= 5) & (so['ans_name'] == 'Scott Boston')]
# select row conditional SELECT * FROM DF WHERE ONE > 1 AND TWO < 5
df.loc[(df['one']>1) & (df['two']<5)]
# Out:
#    one  two
# b  2.0  2.1
# c  3.0  3.5

# %%
df
# Out:
#    one  two
# a  1.0  1.2
# b  2.0  2.1
# c  3.0  3.5
# d  NaN  4.9

# %%
df[df['two']>1.5] # same as before but shorter
# Out:
#    one  two
# b  2.0  2.1
# c  3.0  3.5
# d  NaN  4.9

# %%
df['one']
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
df['one']>1
# Out:
# a    False
# b     True
# c     True
# d    False
# Name: one, dtype: bool

# %%
df[df['one']>1]
# Out:
#    one  two
# b  2.0  2.1
# c  3.0  3.5

# %%
df[df['one']>1]['two'] # SELECT TWO FROM DF WHERE ONE > 1
# Out:
# b    2.1
# c    3.5
# Name: two, dtype: float64

# %%
#Transpose
df[:].T
# Out:
#        a    b    c    d
# one  1.0  2.0  3.0  NaN
# two  1.2  2.1  3.5  4.9

# %%
df[df['one']>1].T
# Out:
#        b    c
# one  2.0  3.0
# two  2.1  3.5
